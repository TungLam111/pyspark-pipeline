# %% [markdown]
# Write a PySpark program using Jupyter notebook to analyze statistically the text files (download from drive) as follows
#
# 1. Count the number of times a word appears in the file
#
# 2. Calculate the most common words in the file
#
# 3. Calculate the average number of appearances of all words.
#
# 4. Calculate the frequency of combination of two words appears in the text file.
#
# 5. Print the two combined words that are the median in term of number of the appearances.
#
# Note:
#
# a) At the beginning of your notebook, run this “sc.getConf().getAll()” to show your configuration.
#
# b) Describe in your own words how you use the Spark API for this problem, explain what Spark functions do in relation to the MapReduce model. Please write your answer in the same notebook using a markdown box.
#
# c) Calculate the running time for each above question.
#
# d) Before submitting your work, stop your current notebook session, the start it again and run all from the beginning.
#
# Your notebook should contains cells counting from 1.
#
# e) You should submit 3 things (Notebook, a pdf/html of your notebook, spark master UI saved as html) in a zip file studentID.zip.

# %% [markdown]
# # Note
# This is run on 1B.language.model.test.txt file. I first run on 1B.language.model.txt with the partition 30000 but it's out of memory in C:/, so I need to shutdown and run on test file.

# %% [markdown]
# import findspark library is optional. This lib is to

# %%
import findspark
findspark.init()

# %%
from pyspark import SparkContext, SparkConf
import re

# %%
conf = SparkConf().setMaster("yarn").setAppName("WordCount")

# %%
sc = SparkContext.getOrCreate (conf = conf)
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).

# %%
sc.getConf().getAll()
# Out:
# [('spark.driver.extraJavaOptions',
#   '-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_HOSTS',
#   'master'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_URI_BASES',
#   'http://master:8088/proxy/application_1667731232494_0004'),
#  ('spark.executor.id', 'driver'),
#  ('spark.app.startTime', '1667735943018'),
#  ('spark.driver.bindAddress', '192.1.1.11'),
#  ('spark.ui.port', '4050'),
#  ('spark.master', 'yarn'),
#  ('spark.app.submitTime', '1667735942005'),
#  ('spark.driver.port', '44967'),
#  ('spark.app.id', 'application_1667731232494_0004'),
#  ('spark.driver.appUIAddress', 'http://edge:4050'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.yarn.jars', ''),
#  ('spark.driver.host', 'edge'),
#  ('spark.executor.extraJavaOptions',
#   '-XX:+IgnoreUnrecognizedVMOptions --add-opens=java.base/java.lang=ALL-UNNAMED --add-opens=java.base/java.lang.invoke=ALL-UNNAMED --add-opens=java.base/java.lang.reflect=ALL-UNNAMED --add-opens=java.base/java.io=ALL-UNNAMED --add-opens=java.base/java.net=ALL-UNNAMED --add-opens=java.base/java.nio=ALL-UNNAMED --add-opens=java.base/java.util=ALL-UNNAMED --add-opens=java.base/java.util.concurrent=ALL-UNNAMED --add-opens=java.base/java.util.concurrent.atomic=ALL-UNNAMED --add-opens=java.base/sun.nio.ch=ALL-UNNAMED --add-opens=java.base/sun.nio.cs=ALL-UNNAMED --add-opens=java.base/sun.security.action=ALL-UNNAMED --add-opens=java.base/sun.util.calendar=ALL-UNNAMED --add-opens=java.security.jgss/sun.security.krb5=ALL-UNNAMED'),
#  ('spark.app.name', 'WordCount'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.executorEnv.PYTHONPATH',
#   '/usr/local/spark/python:<CPS>{{PWD}}/pyspark.zip<CPS>{{PWD}}/py4j-0.10.9.5-src.zip'),
#  ('spark.submit.pyFiles', ''),
#  ('spark.yarn.isPython', 'true'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.ui.filters',
#   'org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.ui.proxyBase', '/proxy/application_1667731232494_0004')]

# %%
'''
Function to remove punctuation and blank sentences.
'''
def removePunctuation(word):
    x = word.lower()
    return re.sub(r'[^\w\s]', '', x)

# %% [markdown]
# Before running on big file, I want to ensure everything works well with small one, so I create a mock RDD with 5 lines. Below is how it looks like. The detail explaination of Spark function is on the next section.

# %%
'''
Mock test for 5 executions. Because it's extremely expensive to process our data, I create a mock test with only 5 first lines 
'''
mock_lineRDD = sc.parallelize(['the us centers for disease control and prevention initially advised school systems to close if outbreaks occurred  then reversed itself  saying the apparent mildness of the virus meant most schools and day care centers should stay open  even if they had confirmed cases of swine flu ',
 'when ms winfrey invited suzanne somers to share her controversial views about bioidentical hormone treatment on her syndicated show in 2009  it won ms winfrey a rare dollop of unflattering press  including a newsweek cover story titled  crazy talk  oprah  wacky cures  you  ',
 'elk calling  a skill that hunters perfected long ago to lure game with the promise of a little romance  is now its own sport ',
 'don t ',
 'fish  ranked 98th in the world  fired 22 aces en route to a 63  67  5  7   76  7  4  win over seventhseeded argentinian david nalbandian '], 3)

# %%
'''mock 1'''
mock_mapReducedCount = mock_lineRDD.flatMap(lambda line: re.split('\s+', line.strip())).map(lambda x: (x,1)).reduceByKey(lambda a , b: a + b)
def mockCountWord(word = None):
    if (word is None) :
        print(mock_mapReducedCount.collect())
    else:
        print(mock_mapReducedCount.filter(lambda z : z[0] == word).collect())
mockCountWord('the')
mockCountWord()
# Out:
# [('the', 5)]
# [Stage 3:===================>                                       (1 + 1) / 3]
# [('the', 5), ('for', 1), ('control', 1), ('prevention', 1), ('advised', 1), ('outbreaks', 1), ('reversed', 1), ('saying', 1), ('of', 4), ('most', 1), ('schools', 1), ('care', 1), ('stay', 1), ('open', 1), ('even', 1), ('they', 1), ('flu', 1), ('when', 1), ('share', 1), ('bioidentical', 1), ('hormone', 1), ('show', 1), ('it', 1), ('unflattering', 1), ('press', 1), ('including', 1), ('newsweek', 1), ('titled', 1), ('oprah', 1), ('cures', 1), ('ago', 1), ('with', 1), ('romance', 1), ('sport', 1), ('t', 1), ('ranked', 1), ('fired', 1), ('22', 1), ('aces', 1), ('route', 1), ('63', 1), ('76', 1), ('4', 1), ('win', 1), ('over', 1), ('seventhseeded', 1), ('argentinian', 1), ('nalbandian', 1), ('and', 2), ('initially', 1), ('systems', 1), ('to', 4), ('if', 2), ('itself', 1), ('apparent', 1), ('virus', 1), ('day', 1), ('had', 1), ('confirmed', 1), ('swine', 1), ('winfrey', 2), ('somers', 1), ('her', 2), ('controversial', 1), ('views', 1), ('about', 1), ('story', 1), ('crazy', 1), ('you', 1), ('elk', 1), ('calling', 1), ('skill', 1), ('that', 1), ('perfected', 1), ('promise', 1), ('little', 1), ('is', 1), ('now', 1), ('its', 1), ('98th', 1), ('world', 1), ('en', 1), ('david', 1), ('us', 1), ('centers', 2), ('disease', 1), ('school', 1), ('close', 1), ('occurred', 1), ('then', 1), ('mildness', 1), ('meant', 1), ('should', 1), ('cases', 1), ('ms', 2), ('invited', 1), ('suzanne', 1), ('treatment', 1), ('on', 1), ('syndicated', 1), ('in', 2), ('2009', 1), ('won', 1), ('a', 5), ('rare', 1), ('dollop', 1), ('cover', 1), ('talk', 1), ('wacky', 1), ('hunters', 1), ('long', 1), ('lure', 1), ('game', 1), ('own', 1), ('don', 1), ('fish', 1), ('67', 1), ('5', 1), ('7', 2)]

# %%
'''mock 2'''
mock_most_common = mock_mapReducedCount.max(lambda x: x[1])
mock_mapReducedCount.filter(lambda z: z[1] == mock_most_common[1]).collect()
# Out:
# [('the', 5), ('a', 5)]

# %%
'''mock 3'''
mock_uniqueWordCount = mock_mapReducedCount.count()
mock_totalWordCount = (mock_mapReducedCount.map(lambda x: x[1]).reduce(lambda a, b: a+b))
mock_avg = mock_totalWordCount / mock_uniqueWordCount
mock_totalWordCount2 = mock_mapReducedCount.values().sum()
print(mock_avg)
print(mock_totalWordCount == mock_totalWordCount2)
# Out:
# 1.184873949579832
# True

# %%
'''mock 4'''

mock_bigrams = mock_lineRDD.map(lambda s : re.split('\s+', s.strip())).flatMap(lambda s: [((s[i],s[i+1]),1) for i in range (0, len(s)-1)])
mock_bigramCounts = mock_bigrams.reduceByKey(lambda x, y : x + y)

def mockCountBigram(word = None):
    if word is None:
        print(mock_bigramCounts.collect())
    else:
        print(mock_bigramCounts.filter(lambda z : ' '.join(z[0]) == word).collect())
mockCountBigram('to share')
mockCountBigram()
# Out:
# [(('to', 'share'), 1)]
# [(('when', 'ms'), 1), (('suzanne', 'somers'), 1), (('somers', 'to'), 1), (('to', 'share'), 1), (('bioidentical', 'hormone'), 1), (('hormone', 'treatment'), 1), (('won', 'ms'), 1), (('a', 'rare'), 1), (('rare', 'dollop'), 1), (('including', 'a'), 1), (('a', 'newsweek'), 1), (('newsweek', 'cover'), 1), (('story', 'titled'), 1), (('titled', 'crazy'), 1), (('crazy', 'talk'), 1), (('wacky', 'cures'), 1), (('cures', 'you'), 1), (('elk', 'calling'), 1), (('calling', 'a'), 1), (('hunters', 'perfected'), 1), (('perfected', 'long'), 1), (('long', 'ago'), 1), (('lure', 'game'), 1), (('game', 'with'), 1), (('the', 'promise'), 1), (('little', 'romance'), 1), (('romance', 'is'), 1), (('own', 'sport'), 1), (('fish', 'ranked'), 1), (('ranked', '98th'), 1), (('in', 'the'), 1), (('aces', 'en'), 1), (('route', 'to'), 1), (('a', '63'), 1), (('5', '7'), 1), (('7', '76'), 1), (('david', 'nalbandian'), 1), (('the', 'us'), 1), (('centers', 'for'), 1), (('and', 'prevention'), 1), (('advised', 'school'), 1), (('school', 'systems'), 1), (('systems', 'to'), 1), (('if', 'outbreaks'), 1), (('then', 'reversed'), 1), (('reversed', 'itself'), 1), (('itself', 'saying'), 1), (('of', 'the'), 1), (('the', 'virus'), 1), (('meant', 'most'), 1), (('day', 'care'), 1), (('care', 'centers'), 1), (('should', 'stay'), 1), (('even', 'if'), 1), (('they', 'had'), 1), (('cases', 'of'), 1), (('swine', 'flu'), 1), (('initially', 'advised'), 1), (('to', 'close'), 1), (('close', 'if'), 1), (('apparent', 'mildness'), 1), (('schools', 'and'), 1), (('centers', 'should'), 1), (('winfrey', 'invited'), 1), (('share', 'her'), 1), (('her', 'controversial'), 1), (('controversial', 'views'), 1), (('treatment', 'on'), 1), (('her', 'syndicated'), 1), (('show', 'in'), 1), (('2009', 'it'), 1), (('it', 'won'), 1), (('winfrey', 'a'), 1), (('dollop', 'of'), 1), (('of', 'unflattering'), 1), (('oprah', 'wacky'), 1), (('a', 'skill'), 1), (('that', 'hunters'), 1), (('to', 'lure'), 1), (('with', 'the'), 1), (('promise', 'of'), 1), (('is', 'now'), 1), (('98th', 'in'), 1), (('the', 'world'), 1), (('en', 'route'), 1), (('63', '67'), 1), (('4', 'win'), 1), (('over', 'seventhseeded'), 1), (('seventhseeded', 'argentinian'), 1), (('argentinian', 'david'), 1), (('ms', 'winfrey'), 2), (('invited', 'suzanne'), 1), (('views', 'about'), 1), (('about', 'bioidentical'), 1), (('on', 'her'), 1), (('syndicated', 'show'), 1), (('in', '2009'), 1), (('unflattering', 'press'), 1), (('press', 'including'), 1), (('cover', 'story'), 1), (('talk', 'oprah'), 1), (('skill', 'that'), 1), (('ago', 'to'), 1), (('of', 'a'), 1), (('a', 'little'), 1), (('now', 'its'), 1), (('its', 'own'), 1), (('don', 't'), 1), (('world', 'fired'), 1), (('fired', '22'), 1), (('22', 'aces'), 1), (('to', 'a'), 1), (('67', '5'), 1), (('76', '7'), 1), (('7', '4'), 1), (('win', 'over'), 1), (('us', 'centers'), 1), (('for', 'disease'), 1), (('disease', 'control'), 1), (('control', 'and'), 1), (('prevention', 'initially'), 1), (('outbreaks', 'occurred'), 1), (('occurred', 'then'), 1), (('saying', 'the'), 1), (('the', 'apparent'), 1), (('mildness', 'of'), 1), (('virus', 'meant'), 1), (('most', 'schools'), 1), (('and', 'day'), 1), (('stay', 'open'), 1), (('open', 'even'), 1), (('if', 'they'), 1), (('had', 'confirmed'), 1), (('confirmed', 'cases'), 1), (('of', 'swine'), 1)]

# %%
'''mock 5'''
mock_countNumBigram = mock_bigramCounts.count()
mock_median_value = None

if mock_countNumBigram % 2 == 0 :
    print('even')
    mock_median_value_with_index = mock_bigramCounts.sortBy(lambda z : z[1]).zipWithIndex().filter(lambda z: z[1] == int(mock_countNumBigram/2) or z[1] == int(countNumBigram/2)-1)
else: 
    print('odd')
    mock_median_value_with_index = mock_bigramCounts.sortBy(lambda z : z[1]).zipWithIndex().filter(lambda z: z[1] == int((mock_countNumBigram - 1)/2))

mock_median_value = mock_median_value_with_index.map(lambda z: z[0]).values().mean()
mock_bigramCounts.filter(lambda z: z[1] == mock_median_value).collect()
# Out:
# odd
# [(('the', 'us'), 1),
#  (('centers', 'for'), 1),
#  (('and', 'prevention'), 1),
#  (('advised', 'school'), 1),
#  (('school', 'systems'), 1),
#  (('systems', 'to'), 1),
#  (('if', 'outbreaks'), 1),
#  (('then', 'reversed'), 1),
#  (('reversed', 'itself'), 1),
#  (('itself', 'saying'), 1),
#  (('of', 'the'), 1),
#  (('the', 'virus'), 1),
#  (('meant', 'most'), 1),
#  (('day', 'care'), 1),
#  (('care', 'centers'), 1),
#  (('should', 'stay'), 1),
#  (('even', 'if'), 1),
#  (('they', 'had'), 1),
#  (('cases', 'of'), 1),
#  (('swine', 'flu'), 1),
#  (('when', 'ms'), 1),
#  (('suzanne', 'somers'), 1),
#  (('somers', 'to'), 1),
#  (('to', 'share'), 1),
#  (('bioidentical', 'hormone'), 1),
#  (('hormone', 'treatment'), 1),
#  (('won', 'ms'), 1),
#  (('a', 'rare'), 1),
#  (('rare', 'dollop'), 1),
#  (('including', 'a'), 1),
#  (('a', 'newsweek'), 1),
#  (('newsweek', 'cover'), 1),
#  (('story', 'titled'), 1),
#  (('titled', 'crazy'), 1),
#  (('crazy', 'talk'), 1),
#  (('wacky', 'cures'), 1),
#  (('cures', 'you'), 1),
#  (('elk', 'calling'), 1),
#  (('calling', 'a'), 1),
#  (('hunters', 'perfected'), 1),
#  (('perfected', 'long'), 1),
#  (('long', 'ago'), 1),
#  (('lure', 'game'), 1),
#  (('game', 'with'), 1),
#  (('the', 'promise'), 1),
#  (('little', 'romance'), 1),
#  (('romance', 'is'), 1),
#  (('own', 'sport'), 1),
#  (('fish', 'ranked'), 1),
#  (('ranked', '98th'), 1),
#  (('in', 'the'), 1),
#  (('aces', 'en'), 1),
#  (('route', 'to'), 1),
#  (('a', '63'), 1),
#  (('5', '7'), 1),
#  (('7', '76'), 1),
#  (('david', 'nalbandian'), 1),
#  (('winfrey', 'invited'), 1),
#  (('share', 'her'), 1),
#  (('her', 'controversial'), 1),
#  (('controversial', 'views'), 1),
#  (('treatment', 'on'), 1),
#  (('her', 'syndicated'), 1),
#  (('show', 'in'), 1),
#  (('2009', 'it'), 1),
#  (('it', 'won'), 1),
#  (('winfrey', 'a'), 1),
#  (('dollop', 'of'), 1),
#  (('of', 'unflattering'), 1),
#  (('oprah', 'wacky'), 1),
#  (('a', 'skill'), 1),
#  (('that', 'hunters'), 1),
#  (('to', 'lure'), 1),
#  (('with', 'the'), 1),
#  (('promise', 'of'), 1),
#  (('is', 'now'), 1),
#  (('98th', 'in'), 1),
#  (('the', 'world'), 1),
#  (('en', 'route'), 1),
#  (('63', '67'), 1),
#  (('4', 'win'), 1),
#  (('over', 'seventhseeded'), 1),
#  (('seventhseeded', 'argentinian'), 1),
#  (('argentinian', 'david'), 1),
#  (('initially', 'advised'), 1),
#  (('to', 'close'), 1),
#  (('close', 'if'), 1),
#  (('apparent', 'mildness'), 1),
#  (('schools', 'and'), 1),
#  (('centers', 'should'), 1),
#  (('invited', 'suzanne'), 1),
#  (('views', 'about'), 1),
#  (('about', 'bioidentical'), 1),
#  (('on', 'her'), 1),
#  (('syndicated', 'show'), 1),
#  (('in', '2009'), 1),
#  (('unflattering', 'press'), 1),
#  (('press', 'including'), 1),
#  (('cover', 'story'), 1),
#  (('talk', 'oprah'), 1),
#  (('skill', 'that'), 1),
#  (('ago', 'to'), 1),
#  (('of', 'a'), 1),
#  (('a', 'little'), 1),
#  (('now', 'its'), 1),
#  (('its', 'own'), 1),
#  (('don', 't'), 1),
#  (('world', 'fired'), 1),
#  (('fired', '22'), 1),
#  (('22', 'aces'), 1),
#  (('to', 'a'), 1),
#  (('67', '5'), 1),
#  (('76', '7'), 1),
#  (('7', '4'), 1),
#  (('win', 'over'), 1),
#  (('us', 'centers'), 1),
#  (('for', 'disease'), 1),
#  (('disease', 'control'), 1),
#  (('control', 'and'), 1),
#  (('prevention', 'initially'), 1),
#  (('outbreaks', 'occurred'), 1),
#  (('occurred', 'then'), 1),
#  (('saying', 'the'), 1),
#  (('the', 'apparent'), 1),
#  (('mildness', 'of'), 1),
#  (('virus', 'meant'), 1),
#  (('most', 'schools'), 1),
#  (('and', 'day'), 1),
#  (('stay', 'open'), 1),
#  (('open', 'even'), 1),
#  (('if', 'they'), 1),
#  (('had', 'confirmed'), 1),
#  (('confirmed', 'cases'), 1),
#  (('of', 'swine'), 1)]

# %% [markdown]
# There are some useful functions in python I utilize in this exercise.
#
# - re.split(regex, string): split a string by a regex expression
#
# - .strip(): remove white spaces at leading and ending positions of a string
#
# - bool(re.match(regex, string)): check if string matches the regex expression

# %% [markdown]
# # 1. Count the number of times a word appears in the file

# %%
'''
This is to read text file in hdfs with 500 partitions.
Firstly, I remove punctuation by applying map function for RDD
Secondly, in order to remove those empty lines, I use filter function with regex check whether that string matches non-empty lines
'''

lineRDD = (sc.textFile("hdfs://master:9000/data", 500).map(lambda x: removePunctuation(x)).filter(lambda z: bool(re.match('^(?!\s*$).+', z)) is True))


'''
I apply flatMap function to lineRDD in order to flatten into a list. Each line is splitted into single words by split
funtion (of python).
In the next step, we apply mapReduce method to extract frequencies of unique words:
    - map: map every words and transform to a tuple of itself and 1
    - reduceByKey

In order to count the number of times a word appears in the file, I would like to create a function with param is a word
'''
mapReducedCount = lineRDD.flatMap(lambda line: re.split('\s+', line.strip())).map(lambda x: (x,1)).reduceByKey(lambda a , b: a + b)

def countWord(word = None):
    if (word is None) :
        print(mapReducedCount.collect())
    else:
        print(mapReducedCount.filter(lambda z : z[0] == word).collect())
        
countWord('hello')
# Out:
# [Stage 33:=====================================================>(495 + 2) / 500]
# [('hello', 124)]

# %% [markdown]
# Measurement from Spark UI, I got
# - Job ID: 15
# - Running time: 2.7 min
#
#
# This execution only contains 1 job because we only have 1 action collect here
#
# -> Total time: 2.7 min

# %% [markdown]
# # 2. Calculate the most common words in the file

# %%
'''
So as to find the most common words in the file, I use max function.
'''
most_common = mapReducedCount.max(lambda x: x[1])
mapReducedCount.filter(lambda z: z[1] == most_common[1]).collect()
# Out:
# [('the', 834484)]

# %% [markdown]
# As measured, we have 2 jobs, respective to max() and collect():
#
# (ID: 16, time: 55s)
#
# (ID: 17, time: 51s)
#
# -> Total time: 1.7 min

# %% [markdown]
# # 3. Calculate the average number of appearances of all words.

# %%
'''
In order to find average number of appearances of all words, we need to find how many distinct words in the data, and
sum of their frequency
'''
uniqueWordCount = mapReducedCount.count()
totalWordCount = (mapReducedCount.map(lambda x: x[1]).reduce(lambda a,b: a + b))
avg = totalWordCount / uniqueWordCount
print(avg)
# Out:
# [Stage 41:=====================================================>(496 + 2) / 500]
# 86.71228496434169

# %% [markdown]
# As measured, we have 2 job, respective to count() and reduce():
#
# (ID: 18, time: 57s)
#
# (ID: 19, time: 51s)
#
# -> Total time: 1.8 min
#
# In addition to use mapReduce method to find total word counts (map every items to their value and aggregate into numeric value (sum)),
# we can also use .values().sum().

# %% [markdown]
# # 4. Calculate the frequency of combination of two words appears in the text file.

# %% [markdown]
# For this problem, on initial lineRDD, I use map() function with tokenization lambda function by re.split(). Every items of lineRDD becomes a list of single words. After that, use flatMap() to, firstly, transform every list of lineRDD to a list of bigrams (with the help of forloop), then flatten into a list of bigrams with count value equal to 1.
# Every items has form ((word1, word2), 1)
#
# Finally, use reduceByKey() function to get RDD of occurences of unique bigrams.
#
# For the rest, I implement a countBigram(string) to get the counts of string. If None, it will run collect()

# %%
bigrams = lineRDD.map(lambda s : re.split('\s+', s.strip())).flatMap(lambda s: [((s[i],s[i+1]),1) for i in range (0, len(s)-1)])
bigramCounts = bigrams.reduceByKey(lambda x, y : x + y)

def countBigram(word = None):
    if word is None:
        print(bigramCounts.collect())
    else:
        print(bigramCounts.filter(lambda z : ' '.join(z[0]) == word).collect())
                      
countBigram('to share')
# Out:
# [Stage 43:=====================================================>(497 + 2) / 500]
# [(('to', 'share'), 320)]

# %% [markdown]
# (ID: 20, time: 3.7 min)
#
# It's obvious that only one action happen here (collect).
#
# -> Total time: 3.7 min

# %% [markdown]
# # 5. Print the two combined words that are the median in term of number of the appearances.

# %% [markdown]
# For this problem, the idea is to find number of unique bigrams first with action count(). There are different ways to find median value but here I sort bigramCounts and transform it to a tuple with zipWithIndex(). Because using collect() and get middle index from the list is expensive, so I want to use filter() function on RDD to find middle index instead. zipWithIndex() coupled with filter() is a great combination.
#
# median_value is a RDD of one item (in case number of count is odd) and two items (in case number of count is even). It will be much more reasonable to check condition and find medium value but here I want to try with .values().mean() though it takes more time to run.

# %%
countNumBigram = bigramCounts.count()
median_value = None

if countNumBigram % 2 == 0 :
    print('Even counts of items')
    median_with_index = bigramCounts.sortBy(lambda z : z[1]).zipWithIndex().filter(lambda z: z[1] == int(countNumBigram/2) or z[1] == int(countNumBigram/2)-1)
else: 
    print('Odd counts of items')
    median_with_index = bigramCounts.sortBy(lambda z : z[1]).zipWithIndex().filter(lambda z: z[1] == int((countNumBigram - 1)/2))

median_value = median_with_index.map(lambda z: z[0]).values().mean()
print('Median of appearances in bigrams counts is {}'.format(median_value))
bigramCounts.filter(lambda z: z[1] == median_value).collect()
# Out:
# Odd counts of items
# Median of appearances in bigrams counts is 2.0
# [(('warrington', 'man'), 2),
#  (('hortaosorio', 'its'), 2),
#  (('coren', 'never'), 2),
#  (('mostly', 'dealing'), 2),
#  (('public', 'produced'), 2),
#  (('pink', 'pink'), 2),
#  (('vampire', 'a'), 2),
#  (('beichuan', 'with'), 2),
#  (('mile', 'as'), 2),
#  (('security', 'test'), 2),
#  (('supplying', 'child'), 2),
#  (('style', 'we'), 2),
#  (('domains', 'include'), 2),
#  (('delayed', '20'), 2),
#  (('system', 'all'), 2),
#  (('backgrounds', 'having'), 2),
#  (('artist', 'always'), 2),
#  (('only', 'pop'), 2),
#  (('kahlenberg', 'a'), 2),
#  (('thrilled', 'as'), 2),
#  (('sound', 'anxious'), 2),
#  (('viewers', 'safely'), 2),
#  (('un', 'monitoring'), 2),
#  (('over', 'settlements'), 2),
#  (('referred', 'him'), 2),
#  (('un', 'sussex'), 2),
#  (('defused', 'tensions'), 2),
#  (('each', 'hotel'), 2),
#  (('killers', 'terrorists'), 2),
#  (('rio', 'doce'), 2),
#  (('chicken', 'scraps'), 2),
#  (('latvian', 'immigrant'), 2),
#  (('impressive', '138'), 2),
#  (('use', 'microsoft'), 2),
#  (('by', 'ipod'), 2),
#  (('lb', 'ashlee'), 2),
#  (('suicide', 'notes'), 2),
#  (('jurisprudence', 'should'), 2),
#  (('that', 'fumes'), 2),
#  (('wallboard', 'that'), 2),
#  (('favors', 'senior'), 2),
#  (('irrepressibly', 'forward'), 2),
#  (('s11', 'dated'), 2),
#  (('illrepaired', 'carretera'), 2),
#  (('ekpe', 'udoh'), 2),
#  (('october', 'have'), 2),
#  (('protocolinspired', 'excess'), 2),
#  (('fortunate', 'when'), 2),
#  (('baby', 'changing'), 2),
#  (('clubhouse', 'more'), 2),
#  (('juice', 'olive'), 2),
#  (('bustling', 'shopping'), 2),
#  (('muchmaligned', 'slow'), 2),
#  (('have', 'mature'), 2),
#  (('principal', 'otis'), 2),
#  (('global', 'solution'), 2),
#  (('still', 'trumps'), 2),
#  (('planes', 'until'), 2),
#  (('bluegreen', 'stripe'), 2),
#  (('for', 'sixparty'), 2),
#  (('then', 'gobble'), 2),
#  (('catheters', 'sometimes'), 2),
#  (('other', 'villages'), 2),
#  (('bruises', 'if'), 2),
#  (('at', 'wood'), 2),
#  (('its', 'dopesmoking'), 2),
#  (('stoneeating', 'organisms'), 2),
#  (('slava', 'kozlov'), 2),
#  (('airlines', 'http'), 2),
#  (('went', 'outofbounds'), 2),
#  (('many', 'minor'), 2),
#  (('into', 'i'), 2),
#  (('be', 'methodically'), 2),
#  (('like', 'pre'), 2),
#  (('disney', 'studio'), 2),
#  (('nixon', 'is'), 2),
#  (('nothing', 'trumps'), 2),
#  (('special', 'burden'), 2),
#  (('sing', 'i'), 2),
#  (('fundraiser', 'five'), 2),
#  (('crusoe', 'island'), 2),
#  (('kopitar', 'scored'), 2),
#  (('turmoil', 'including'), 2),
#  (('farhan', 'who'), 2),
#  (('conquer', 'but'), 2),
#  (('actors', 'actors'), 2),
#  (('bangladeshi', 'girl'), 2),
#  (('test', 'blast'), 2),
#  (('post', 'yelled'), 2),
#  (('respondents', 'holding'), 2),
#  (('canadian', 'coal'), 2),
#  (('traditional', 'route'), 2),
#  (('bases', 'every'), 2),
#  (('package', 'signed'), 2),
#  (('off', 'abereddi'), 2),
#  (('observed', 'philip'), 2),
#  (('period', 'try'), 2),
#  (('ad', 'also'), 2),
#  (('raggett', 'alleged'), 2),
#  (('am', 'tail'), 2),
#  (('jia', 'yinghua'), 2),
#  (('mazda', 'recovering'), 2),
#  (('stassen', 'is'), 2),
#  (('kemp', 'chased'), 2),
#  (('blue', 'abusive'), 2),
#  (('mount', 'for'), 2),
#  (('at', 'morocco'), 2),
#  (('bedroom', 'detached'), 2),
#  (('mocking', 'politicians'), 2),
#  (('there', 'these'), 2),
#  (('for', 'rebiya'), 2),
#  (('president', 'club'), 2),
#  (('what', 'qualifications'), 2),
#  (('earth', 'wld'), 2),
#  (('just', 'cyber'), 2),
#  (('its', 'songwriters'), 2),
#  (('be', 'irritatingly'), 2),
#  (('change', 'towards'), 2),
#  (('get', 'overpaid'), 2),
#  (('player', 'tim'), 2),
#  (('england', 'amid'), 2),
#  (('ocean', 'free'), 2),
#  (('normally', 'sensitive'), 2),
#  (('from', 'luke'), 2),
#  (('clothing', 'sales'), 2),
#  (('afroperuvian', 'people'), 2),
#  (('over', 'recall'), 2),
#  (('unique', 'place'), 2),
#  (('for', 'stun'), 2),
#  (('company', 'ostensibly'), 2),
#  (('you', 'dial'), 2),
#  (('unanimously', 'tuesday'), 2),
#  (('a', 'kazakh'), 2),
#  (('anxiety', 'can'), 2),
#  (('mumbai', 'chabad'), 2),
#  (('the', 'soupedup'), 2),
#  (('billboard', 'of'), 2),
#  (('world', 'cultures'), 2),
#  (('heller', 'aka'), 2),
#  (('by', 'despair'), 2),
#  (('colleagues', 'observed'), 2),
#  (('s', 'bistro'), 2),
#  (('tragedy', 'occurred'), 2),
#  (('states', 'agree'), 2),
#  (('marriage', 'foes'), 2),
#  (('higher', 'business'), 2),
#  (('usa', 'moreover'), 2),
#  (('mcdonnell', 'none'), 2),
#  (('zoology', 'that'), 2),
#  (('vivacious', 'personality'), 2),
#  (('said', 'laurie'), 2),
#  (('meanwhile', 'makola'), 2),
#  (('his', '1936'), 2),
#  (('170', 'per'), 2),
#  (('expenses', 'using'), 2),
#  (('loss', 'friday'), 2),
#  (('ibm', 'scientists'), 2),
#  (('to', 'republish'), 2),
#  (('halfcourt', 'lategame'), 2),
#  (('02', 'wallace'), 2),
#  (('lag', 'symptoms'), 2),
#  (('truman', 'has'), 2),
#  (('wonderful', 'consistency'), 2),
#  (('what', 'conan'), 2),
#  (('m', 'caring'), 2),
#  (('through', 'british'), 2),
#  (('at', 'butterfly'), 2),
#  (('third', 'quickest'), 2),
#  (('here', 'couple'), 2),
#  (('wealthiest', 'businessmen'), 2),
#  (('planning', 'days'), 2),
#  (('undermines', 'a'), 2),
#  (('beat', 'palermo'), 2),
#  (('torress', 'levett'), 2),
#  (('signage', 'solution'), 2),
#  (('amended', 'penal'), 2),
#  (('bonafide', '501'), 2),
#  (('large', 'improvement'), 2),
#  (('experienced', 'american'), 2),
#  (('truly', 'let'), 2),
#  (('shown', 'leaving'), 2),
#  (('grazing', 'the'), 2),
#  (('get', 'rejected'), 2),
#  (('two', 'taiwan'), 2),
#  (('2360', 'victories'), 2),
#  (('two', 'entitled'), 2),
#  (('mayhew', 'whose'), 2),
#  (('2454kilometer', '1525mile'), 2),
#  (('ownership', 'joining'), 2),
#  (('from', 'trauma'), 2),
#  (('full', 'commission'), 2),
#  (('zionists', 'found'), 2),
#  (('at', 'tenerife'), 2),
#  (('classic', 'celebrity'), 2),
#  (('terrorism', 'over'), 2),
#  (('produces', 'half'), 2),
#  (('fleeing', 'in'), 2),
#  (('effort', 'too'), 2),
#  (('frank', 'nouble'), 2),
#  (('president', 'useless'), 2),
#  (('telling', 'all'), 2),
#  (('technical', 'findings'), 2),
#  (('record', 'programming'), 2),
#  (('police', 'chopper'), 2),
#  (('carlton', 'ashmansamuels'), 2),
#  (('bush', 'finished'), 2),
#  (('kashmiri', 'terror'), 2),
#  (('the', 'bonhomie'), 2),
#  (('what', 'body'), 2),
#  (('ordered', 'our'), 2),
#  (('mugabe', 'had'), 2),
#  (('or', 'dehydroepiandrosterone'), 2),
#  (('attack', 'represented'), 2),
#  (('mikel', 'obi'), 2),
#  (('m4', 'lending'), 2),
#  (('smith', 'limited'), 2),
#  (('previous', 'un'), 2),
#  (('control', 'apic'), 2),
#  (('post48', 'weeks'), 2),
#  (('the', 'ijams'), 2),
#  (('15man', 'squad'), 2),
#  (('erosion', 'while'), 2),
#  (('push', 'barges'), 2),
#  (('caffeine', 'produced'), 2),
#  (('ridgeline', 'where'), 2),
#  (('third', 'potential'), 2),
#  (('now', 'limited'), 2),
#  (('international', 'pet'), 2),
#  (('y9476', 'while'), 2),
#  (('aerial', 'common'), 2),
#  (('notorious', 'wartime'), 2),
#  (('499', 'race'), 2),
#  (('movies', 'music'), 2),
#  (('thefts', 'assaults'), 2),
#  (('their', 'denon'), 2),
#  (('inc', 'intel'), 2),
#  (('napier', 'felt'), 2),
#  (('quizzed', 'we'), 2),
#  (('debut', 'still'), 2),
#  (('grasp', 'them'), 2),
#  (('alpine', 'village'), 2),
#  (('costs', 'boosted'), 2),
#  (('no', 'regular'), 2),
#  (('two', 'sonswere'), 2),
#  (('also', 'selfish'), 2),
#  (('and', 'alumnae'), 2),
#  (('him', 'marks'), 2),
#  (('science', 'would'), 2),
#  (('only', 'eleven'), 2),
#  (('and', 'extrinsic'), 2),
#  (('no', 'teen'), 2),
#  (('of', 'calendar'), 2),
#  (('unhinge', 'even'), 2),
#  (('these', 'amateur'), 2),
#  (('sawmill', 'takes'), 2),
#  (('tsvangirai', 'yesterday'), 2),
#  (('innocent', 's'), 2),
#  (('visit', 'rachel'), 2),
#  (('giving', 'police'), 2),
#  (('operators', 'based'), 2),
#  (('otherwise', 'for'), 2),
#  (('romanian', 'olympian'), 2),
#  (('a', 'youarethere'), 2),
#  (('hammond', 'b3'), 2),
#  (('used', 'inaccurate'), 2),
#  (('colled', 'enfawr'), 2),
#  (('haunting', 'politics'), 2),
#  (('quarter', 'chevron'), 2),
#  (('to', '45710'), 2),
#  (('kagan', 'attorney'), 2),
#  (('the', 'parliamentuk'), 2),
#  (('items', 'import'), 2),
#  (('sulawesi', 'and'), 2),
#  (('birney', 'president'), 2),
#  (('deviate', 'as'), 2),
#  (('emitter', 'in'), 2),
#  (('costabile', 'farace'), 2),
#  (('workers', 'retirees'), 2),
#  (('fighting13', 'dead'), 2),
#  (('portentous', 'angular'), 2),
#  (('francisco', 'along'), 2),
#  (('gwmh', 'in'), 2),
#  (('anchoring', 'the'), 2),
#  (('nimble', 'assurance'), 2),
#  (('novels', 'were'), 2),
#  (('hit', 'baby'), 2),
#  (('and', 'undertook'), 2),
#  (('booking', 'essential'), 2),
#  (('state', 'shaping'), 2),
#  (('ticket', 'revenues'), 2),
#  (('lesson', 'too'), 2),
#  (('arsenal', 'breathing'), 2),
#  (('s', 'caves'), 2),
#  (('air', '30'), 2),
#  (('spend', 'another'), 2),
#  (('international', 'player'), 2),
#  (('paradise', 'on'), 2),
#  (('surging', 'property'), 2),
#  (('call', 'mean'), 2),
#  (('2010', 'ca'), 2),
#  (('while', 'bb'), 2),
#  (('just', 'nonscientific'), 2),
#  (('coworker', 'inside'), 2),
#  (('like', 'arguing'), 2),
#  (('appointment', 'instead'), 2),
#  (('commission', 'scotland'), 2),
#  (('soulful', 'young'), 2),
#  (('served', '19'), 2),
#  (('refrigerator', 'comes'), 2),
#  (('17thminute', 'after'), 2),
#  (('finger', 'rapidly'), 2),
#  (('76', 'kasabatannourcom'), 2),
#  (('safe', 'geithner'), 2),
#  (('that', 'v2v'), 2),
#  (('mccoy', '6foot5'), 2),
#  (('of', 'tishman'), 2),
#  (('motor', 'of'), 2),
#  (('threw', '77'), 2),
#  (('lee', 'rapper'), 2),
#  (('tamils', 'areas'), 2),
#  (('how', 'considering'), 2),
#  (('binding', 'specificity'), 2),
#  (('york', 'alex'), 2),
#  (('duet', 'for'), 2),
#  (('operates', 'globally'), 2),
#  (('scored', 'off'), 2),
#  (('the', 'basest'), 2),
#  (('republican', 'knows'), 2),
#  (('diver', 'handicap'), 2),
#  (('computation', 'in'), 2),
#  (('violently', 'in'), 2),
#  (('woolas', 'wears'), 2),
#  (('seamstresses', 'fabric'), 2),
#  (('deal', 'democrats'), 2),
#  (('democratic', 'withdrawal'), 2),
#  (('year', 'pointed'), 2),
#  (('boyfriends', 'and'), 2),
#  (('resuscitate', 'a'), 2),
#  (('grown', 'severe'), 2),
#  (('developing', 'esophageal'), 2),
#  (('verb', 'during'), 2),
#  (('vehicle', 'under'), 2),
#  (('uneasy', 'challenge'), 2),
#  (('own', 'vision'), 2),
#  (('parents', 'shared'), 2),
#  (('one', 'closet'), 2),
#  (('his', 'unconscious'), 2),
#  (('senior', 'dell'), 2),
#  (('to', 'getand'), 2),
#  (('jj', 'smyth'), 2),
#  (('interrogation', 'habitually'), 2),
#  (('restore', 'limb'), 2),
#  (('folksy', 'huntin'), 2),
#  (('well', 'orecchiette'), 2),
#  (('personyears', 'of'), 2),
#  (('84', 'households'), 2),
#  (('then', 'hong'), 2),
#  (('proposal', 'they'), 2),
#  (('criticized', 'that'), 2),
#  (('2', 'former'), 2),
#  (('to', '776'), 2),
#  (('the', 'r227'), 2),
#  (('roadside', 'near'), 2),
#  (('inexplicably', 'anemic'), 2),
#  (('political', 'fix'), 2),
#  (('precious', 'gift'), 2),
#  (('organizing', 'an'), 2),
#  (('neuropathology', 'at'), 2),
#  (('or', 'swaying'), 2),
#  (('seemingly', 'unbridgeable'), 2),
#  (('declines', '40'), 2),
#  (('without', 'reliable'), 2),
#  (('compete', 'well'), 2),
#  (('israeli', 'companies'), 2),
#  (('swinging', 'batons'), 2),
#  (('with', 'graygreen'), 2),
#  (('breaking', 'party'), 2),
#  (('more', 'icing'), 2),
#  (('521', 'percent'), 2),
#  (('galleon', 'investors'), 2),
#  (('the', 'eroded'), 2),
#  (('subscription', 'gaming'), 2),
#  (('mpg', 'overall'), 2),
#  (('named', 'he'), 2),
#  (('mrs', 'casagranda'), 2),
#  (('affects', '5'), 2),
#  (('radios', 'borrowed'), 2),
#  (('mandelson', 'over'), 2),
#  (('labeled', 'affordable'), 2),
#  (('for', 'gis'), 2),
#  (('mexico', 'because'), 2),
#  (('roberts', 'similarly'), 2),
#  (('screenwriters', 'trudge'), 2),
#  (('nbc', 'local'), 2),
#  (('odinga', 'served'), 2),
#  (('against', 'governmentowned'), 2),
#  (('fighting', 'heavily'), 2),
#  (('juanita', 'ward'), 2),
#  (('world', 'deals'), 2),
#  (('being', 'closer'), 2),
#  (('afganistan', 'he'), 2),
#  (('magnificent', 'complexity'), 2),
#  (('negotiations', 'when'), 2),
#  (('barney', 'the'), 2),
#  (('about', 'cheap'), 2),
#  (('of', 'cebus'), 2),
#  (('conventional', 'submarine'), 2),
#  (('airways', 'told'), 2),
#  (('is', 'democrats'), 2),
#  (('of', 'frayed'), 2),
#  (('including', 'sanctions'), 2),
#  (('professional', 'concerns'), 2),
#  (('shoresize', 'crowd'), 2),
#  (('8583m', 'in'), 2),
#  (('green', 'dream'), 2),
#  (('manmade', 'climate'), 2),
#  (('wounded', 'soldier'), 2),
#  (('failsafe', 'options'), 2),
#  (('all', 'mortgages'), 2),
#  (('psychologically', 'smaller'), 2),
#  (('roommates', 'who'), 2),
#  (('seamer', 'doesn'), 2),
#  (('the', 'amel'), 2),
#  (('concluding', 'prosecutors'), 2),
#  (('charles', 'completed'), 2),
#  (('http', 'wwwpyrcom'), 2),
#  (('from', 'tracey'), 2),
#  (('653', 'million'), 2),
#  (('diego', 'february'), 2),
#  (('insuring', 'that'), 2),
#  (('professional', 'pressure'), 2),
#  (('thefts', 'have'), 2),
#  (('opening', 'exchanges'), 2),
#  (('enter', 'living'), 2),
#  (('during', 'vice'), 2),
#  (('within', 'island'), 2),
#  (('feudal', 'past'), 2),
#  (('v', 'barry'), 2),
#  (('trouble', 'costello'), 2),
#  (('road', 'writing'), 2),
#  (('underlying', 'human'), 2),
#  (('anniversary', 'spectacular'), 2),
#  (('multiple', 'spouses'), 2),
#  (('oversized', 'dunkin'), 2),
#  (('widespread', 'acts'), 2),
#  (('political', 'dynamo'), 2),
#  (('more', 'steadily'), 2),
#  (('jarvik', 'heart'), 2),
#  (('vtol', 'drone'), 2),
#  (('twinkling', 'christmas'), 2),
#  (('discard', 'enough'), 2),
#  (('indianamerican', 'governor'), 2),
#  (('anticipated', 'a'), 2),
#  (('was', 'bryan'), 2),
#  (('provincial', 'coroner'), 2),
#  (('dickson', 'is'), 2),
#  (('single', 'killing'), 2),
#  (('less', 'pressing'), 2),
#  (('castle', 'without'), 2),
#  (('embarrassing', 'defeats'), 2),
#  (('sex', 'conversations'), 2),
#  (('farmingham', 'mich'), 2),
#  (('hemingford', 'neb'), 2),
#  (('no', 'carbon'), 2),
#  (('usflagged', 'fishing'), 2),
#  (('monies', 'of'), 2),
#  (('gate', 'couldn'), 2),
#  (('forget', 'investors'), 2),
#  (('get', 'robo'), 2),
#  (('after', 'paris'), 2),
#  (('wrinkly', 'skin'), 2),
#  (('obama', 'talked'), 2),
#  (('champion', 'stuart'), 2),
#  (('2002', 'more'), 2),
#  (('young', 'student'), 2),
#  (('of', 'ladies'), 2),
#  (('lower', 'concentrations'), 2),
#  (('with', 'hirschfeld'), 2),
#  (('opiumfree', 'democracy'), 2),
#  (('uninsured', 'hispanic'), 2),
#  (('mountain', 'city'), 2),
#  (('redesign', 'is'), 2),
#  (('america', 'reached'), 2),
#  (('pickup', 'game'), 2),
#  (('danny', 'leiner'), 2),
#  (('87', 'inmates'), 2),
#  (('and', 'insistence'), 2),
#  (('pilot', 'sources'), 2),
#  (('better', 'combines'), 2),
#  (('parts', 'while'), 2),
#  (('episodes', 'soon'), 2),
#  (('course', 'brad'), 2),
#  (('spread', 'democracy'), 2),
#  (('cellular', 'power'), 2),
#  (('and', 'devestated'), 2),
#  (('curling', 'is'), 2),
#  (('steve', 'lake'), 2),
#  (('crude', 'processing'), 2),
#  (('we', 'rush'), 2),
#  (('fled', 'for'), 2),
#  (('however', 'established'), 2),
#  (('prices', 'generally'), 2),
#  (('hit', 'sex'), 2),
#  (('tew', 'natural'), 2),
#  (('splash', 'and'), 2),
#  (('critical', 'bloc'), 2),
#  (('eddery', 'rode'), 2),
#  (('by', 'stupidity'), 2),
#  (('environmental', 'writer'), 2),
#  (('wife', 'carol'), 2),
#  (('by', 'daring'), 2),
#  (('her', 'commute'), 2),
#  (('collegeage', 'volunteers'), 2),
#  (('booming', 'said'), 2),
#  (('coldwar', 'conspiracy'), 2),
#  (('regional', 'councillor'), 2),
#  (('madeleine', 'as'), 2),
#  (('for', 'admittance'), 2),
#  (('allied', 'officers'), 2),
#  (('to', '68678'), 2),
#  (('particularly', 'apparent'), 2),
#  (('margiela', 'was'), 2),
#  (('blah', 'girls'), 2),
#  (('passages', 'where'), 2),
#  (('writers', 'hundreds'), 2),
#  (('solidarity', 'its'), 2),
#  (('harman', 'complains'), 2),
#  (('jean', 'mtv'), 2),
#  (('meals', 'have'), 2),
#  (('season', 'recorded'), 2),
#  (('detecting', 'them'), 2),
#  (('canal', 'thinking'), 2),
#  (('glass', 'line'), 2),
#  (('creative', 'makeover'), 2),
#  (('fashion', 'students'), 2),
#  (('dingle', 'kiss'), 2),
#  (('tossed', 'three'), 2),
#  (('extend', 'ahead'), 2),
#  (('pringle', 'who'), 2),
#  (('two', 'clicks'), 2),
#  (('showed', '29'), 2),
#  (('regional', 'portfolio'), 2),
#  (('firstborn', 'in'), 2),
#  (('for', 'judging'), 2),
#  (('gregg', 'would'), 2),
#  (('mascarenhas', 'from'), 2),
#  (('11', 'one'), 2),
#  (('electronic', 'camera'), 2),
#  (('2012', 'increased'), 2),
#  (('editor', 'fighting'), 2),
#  (('subsidiary', 'resulting'), 2),
#  (('spokesman', 'suggested'), 2),
#  (('disturbance', 'a'), 2),
#  (('1', 'ban'), 2),
#  (('deliver', 'so'), 2),
#  (('growth', 'ensure'), 2),
#  (('foundation', 'tourism'), 2),
#  (('leslie', 'sigman'), 2),
#  (('armed', 'protection'), 2),
#  (('mercury', 'will'), 2),
#  (('produce', 'oxygen'), 2),
#  (('against', 'claims'), 2),
#  (('markets', 'plunge'), 2),
#  (('longstanding', 'tensions'), 2),
#  (('genetically', 'modify'), 2),
#  (('skill', 'doing'), 2),
#  (('exiting', 'gaza'), 2),
#  (('marshall', 'school'), 2),
#  (('festivities', 'celebrating'), 2),
#  (('shiites', 'working'), 2),
#  (('d', 'sentz'), 2),
#  (('crime', 'organised'), 2),
#  (('envoy', 'sergio'), 2),
#  (('step', 'public'), 2),
#  (('of', 'dla'), 2),
#  (('grammys', 'his'), 2),
#  (('confused', 'situation'), 2),
#  (('enjoyed', 'immensely'), 2),
#  (('demonstrations', 'food'), 2),
#  (('tarantino', 'explained'), 2),
#  (('require', 'nearly'), 2),
#  (('age', 'hormone'), 2),
#  (('kites', 'diving'), 2),
#  (('missions', 'even'), 2),
#  (('visit', 'corporbitzcom'), 2),
#  (('one', 'deeply'), 2),
#  (('constitutional', 'doctrine'), 2),
#  (('constant', 'onslaught'), 2),
#  (('domestic', 'tourism'), 2),
#  (('company', 'almost'), 2),
#  (('massproducing', 'one'), 2),
#  (('share', 'meaning'), 2),
#  (('but', 'partisan'), 2),
#  (('norway', 'police'), 2),
#  (('goose', 'as'), 2),
#  (('soccer', 'feet'), 2),
#  (('offering', 'homeowners'), 2),
#  (('admitted', 'strangling'), 2),
#  (('toyota', 'including'), 2),
#  (('living', 'something'), 2),
#  (('savers', 'would'), 2),
#  (('agency', 'representative'), 2),
#  (('interim', 'protection'), 2),
#  (('cuomo', 'did'), 2),
#  (('very', 'knowledgeable'), 2),
#  (('nation', 'saudi'), 2),
#  (('occasions', 'said'), 2),
#  (('statinsalthough', 'statins'), 2),
#  (('tricks', 'prevented'), 2),
#  (('not', 'repeating'), 2),
#  (('landfills', 'but'), 2),
#  (('two', 'cockpits'), 2),
#  (('revenues', 'reached'), 2),
#  (('small', 'dish'), 2),
#  (('conceded', 'penalties'), 2),
#  (('10', 'jefferson'), 2),
#  (('price', 'chair'), 2),
#  (('said', 'maritime'), 2),
#  (('group', 'succumbed'), 2),
#  (('by', 'thinktank'), 2),
#  (('road', 'open'), 2),
#  (('nobody', 'enjoys'), 2),
#  (('the', '197273'), 2),
#  (('pratfalls', 'of'), 2),
#  (('ap', 'robinson'), 2),
#  (('résumé', 'for'), 2),
#  (('for', 'interrupting'), 2),
#  (('67', 'which'), 2),
#  (('of', 'hmv'), 2),
#  (('detection', 'discriminate'), 2),
#  (('twisted', 'way'), 2),
#  (('when', 'third'), 2),
#  (('him', 'attain'), 2),
#  (('his', 'virginia'), 2),
#  (('doubts', 'remained'), 2),
#  (('group', 'performs'), 2),
#  (('cages', 'were'), 2),
#  (('grant', 'wasn'), 2),
#  (('3141', 'yards'), 2),
#  (('florida', 'seized'), 2),
#  (('versus', 'q1'), 2),
#  (('catholic', 'gave'), 2),
#  (('lake', 'windermere'), 2),
#  (('colonial', 'compared'), 2),
#  (('lawyers', 'called'), 2),
#  (('and', 'defensiveness'), 2),
#  (('policeman', 'raised'), 2),
#  (('jolted', 'on'), 2),
#  (('adrian', 'pillivant'), 2),
#  (('sheet', 'spoke'), 2),
#  (('backward', 'administrators'), 2),
#  (('situated', 'financial'), 2),
#  (('such', 'certainty'), 2),
#  (('tumbled', 'nearly'), 2),
#  (('full', 'threeyear'), 2),
#  (('explosion', 'carried'), 2),
#  (('pei', 'lifetime'), 2),
#  (('citibank', 'ceo'), 2),
#  (('implicating', 'prenatal'), 2),
#  (('after', 'philadelphia'), 2),
#  (('hangar', 'to'), 2),
#  (('selfproclaimed', 'mastermind'), 2),
#  (('colleran', 'was'), 2),
#  (('turin', 'despite'), 2),
#  (('while', 'condominium'), 2),
#  (('judges', 'law'), 2),
#  (('sweden', 'want'), 2),
#  (('fold', 'it'), 2),
#  (('a', 'traditionally'), 2),
#  (('toward', 'providing'), 2),
#  (('panik', 'panik'), 2),
#  (('minghella', 's'), 2),
#  (('most', 'financials'), 2),
#  (('in', 'mt'), 2),
#  (('team', 'summit'), 2),
#  (('involve', 'national'), 2),
#  (('club', 'case'), 2),
#  (('study', 'suggesting'), 2),
#  (('was', 'unaccountably'), 2),
#  (('s', 'opus'), 2),
#  (('scheme', 'document'), 2),
#  (('flown', '11'), 2),
#  (('citi', 'habitats'), 2),
#  (('university', 'australia'), 2),
#  (('farsighted', 'war'), 2),
#  (('prison', 'gangster'), 2),
#  (('1944', 'vicepresident'), 2),
#  (('harley', 'cofounder'), 2),
#  (('mid1980s', 'with'), 2),
#  (('nano', 'has'), 2),
#  (('revamping', 'entitlement'), 2),
#  (('outsize', 'returns'), 2),
#  (('linda', 'chavez'), 2),
#  (('momentum', 'back'), 2),
#  (('where', 'mailer'), 2),
#  (('canada', 'alaska'), 2),
#  (('shocks', 'and'), 2),
#  (('against', 'villanova'), 2),
#  (('oil', 'cost'), 2),
#  (('including', 'sony'), 2),
#  (('regular', 'bags'), 2),
#  (('told', 'clients'), 2),
#  (('six', 'received'), 2),
#  (('conservative', 'predecessor'), 2),
#  (('lengths', 'back'), 2),
#  (('hang', 'of'), 2),
#  (('than', 'spelling'), 2),
#  (('mild', 'judgmental'), 2),
#  (('worthy', 'schemes'), 2),
#  (('legal', 'tangle'), 2),
#  (('currently', 'takes'), 2),
#  (('insiders', 'dennis'), 2),
#  (('nearsighted', 'about'), 2),
#  (('photography', 'at'), 2),
#  (('56yearold', 'chambers'), 2),
#  (('and', 'connectors'), 2),
#  (('against', 'togo'), 2),
#  (('wailed', 'and'), 2),
#  (('trapped', 'solar'), 2),
#  (('inaugural', 'hong'), 2),
#  (('to', 'chichester'), 2),
#  (('invariably', 'found'), 2),
#  (('george', '1st'), 2),
#  (('development', 'really'), 2),
#  (('wage', 'as'), 2),
#  (('betterthe', '84000'), 2),
#  (('chechen', 'secessionists'), 2),
#  (('and', 'mice'), 2),
#  (('process', 'says'), 2),
#  (('developed', 'created'), 2),
#  (('some', 'spectators'), 2),
#  (('happen', 'says'), 2),
#  (('billion', 'turning'), 2),
#  (('7731', 'million'), 2),
#  (('hotel', 'grounds'), 2),
#  (('great', 'mass'), 2),
#  (('the', 'homebaked'), 2),
#  (('percent', 'noted'), 2),
#  (('surgery', 'consultant'), 2),
#  (('informal', 'schmid'), 2),
#  (('eclipse', 'air'), 2),
#  (('connerly', 'former'), 2),
#  (('celebrate', 'elias'), 2),
#  (('christopher', 'mcrae'), 2),
#  (('fortification', 'of'), 2),
#  (('canberra', 'put'), 2),
#  (('world', 'produce'), 2),
#  (('intense', 'concentration'), 2),
#  (('tribes', 'dorchester'), 2),
#  (('is', '125cm'), 2),
#  (('ballard', 'who'), 2),
#  (('hadfield', 'street'), 2),
#  (('deliver', 'n'), 2),
#  (('wish', 'without'), 2),
#  (('onto', 'six'), 2),
#  (('lefthander', 'jimmy'), 2),
#  (('powder', 'finer'), 2),
#  (('us', 'curious'), 2),
#  (('cars', 'http'), 2),
#  (('earlier', 'boosted'), 2),
#  (('saw', 'today'), 2),
#  (('film', 'while'), 2),
#  (('2010', 'period'), 2),
#  (('best', 'excuse'), 2),
#  (('heaton', 'bradford'), 2),
#  (('excessive', 'with'), 2),
#  (('the', '10leg'), 2),
#  (('league', 'wembley'), 2),
#  (('robert', 'nisbet'), 2),
#  (('hit', 'mainly'), 2),
#  (('church', 'headquarters'), 2),
#  (('in', 'latimer'), 2),
#  (('outlying', 'car'), 2),
#  (('steve', 'brown'), 2),
#  (('interviews', 'this'), 2),
#  (('fewer', 'waves'), 2),
#  (('country', 'very'), 2),
#  (('donationearning', 'designs'), 2),
#  (('talented', 'media'), 2),
#  (('and', 'onair'), 2),
#  (('aerospace', 'equipment'), 2),
#  (('ridiculous', 'manner'), 2),
#  (('were', 'spatially'), 2),
#  (('facetoface', 'advice'), 2),
#  (('ufc', '86'), 2),
#  (('exports', 'virtually'), 2),
#  (('association', 'club'), 2),
#  (('fatherless', 'mammal'), 2),
#  (('kolkata', 'knight'), 2),
#  (('paediatrics', 'at'), 2),
#  (('even', 'abstract'), 2),
#  (('first', 'adult'), 2),
#  (('same', 'advantage'), 2),
#  (('her', 'windshield'), 2),
#  (('stressful', 'inconvenient'), 2),
#  (('lebanese', 'politicians'), 2),
#  (('upgraded', 'his'), 2),
#  (('mainly', 'solar'), 2),
#  (('midmorning', 'blast'), 2),
#  (('comatose', 'state'), 2),
#  (('as', 'perchloroethylene'), 2),
#  (('under', 'sony'), 2),
#  (('some', 'striking'), 2),
#  (('3128', 'lead'), 2),
#  (('at', 'bia'), 2),
#  (('who', 'posts'), 2),
#  (('944', 'which'), 2),
#  (('tyrannical', 'govt'), 2),
#  (('over', 'black'), 2),
#  (('win', 'like'), 2),
#  (('day', 'under'), 2),
#  (('then', 'halfway'), 2),
#  (('but', 'hurry'), 2),
#  (('meeting', 'apparently'), 2),
#  (('to', 'davone'), 2),
#  (('saga', 'and'), 2),
#  (('india', '2008'), 2),
#  (('and', 'crevices'), 2),
#  (('on', 'sanctuary'), 2),
#  (('alfaraj', 'supported'), 2),
#  (('bogeyfree', '66'), 2),
#  (('university', 'relating'), 2),
#  (('with', 'orchestra'), 2),
#  (('facebook', 'boasts'), 2),
#  (('gun', 'we'), 2),
#  (('yesterday', 'along'), 2),
#  (('own', 'stricter'), 2),
#  (('gp', 'understood'), 2),
#  (('through', 'mangrove'), 2),
#  (('against', 'kings'), 2),
#  (('svrs', 'so'), 2),
#  (('like', 'netflix'), 2),
#  (('17thcentury', 'pot'), 2),
#  (('1', '12874'), 2),
#  (('of', 'undertakings'), 2),
#  (('walmart', 'agreed'), 2),
#  (('political', 'marginalization'), 2),
#  (('china', 'flexing'), 2),
#  (('victoria', 'a'), 2),
#  (('bad', 'infrastructure'), 2),
#  (('se', 'mettait'), 2),
#  (('37', 'filipe'), 2),
#  (('investigating', 'very'), 2),
#  (('the', 'jizan'), 2),
#  (('their', 'followthrough'), 2),
#  (('neighborhoods', 'police'), 2),
#  (('retirement', 'rules'), 2),
#  (('with', 'enjoyment'), 2),
#  (('as', 'courtney'), 2),
#  (('its', 'pantograph'), 2),
#  (('they', 'conceive'), 2),
#  (('selwood', 'said'), 2),
#  (('francewhich', 'led'), 2),
#  (('elusive', 'carmen'), 2),
#  (('year', 'published'), 2),
#  (('were', 'game'), 2),
#  (('polling', 'as'), 2),
#  (('conviction', 'should'), 2),
#  (('dunlap', 'hours'), 2),
#  (('partner', 'steveo'), 2),
#  (('1600meter', 'relays'), 2),
#  (('provocative', 'fire'), 2),
#  (('44bn', 'deal'), 2),
#  (('converting', 'other'), 2),
#  (('andy', 'lloyd'), 2),
#  (('for', 'younes'), 2),
#  (('flood', 'completed'), 2),
#  (('investigations', 'confirmed'), 2),
#  (('both', 'booms'), 2),
#  (('the', 'linebacker'), 2),
#  (('lanka', 'was'), 2),
#  (('street', 'fired'), 2),
#  (('memoirs', 'more'), 2),
#  (('eindhoven', 'about'), 2),
#  (('rigidly', 'protected'), 2),
#  (('industry', 'if'), 2),
#  (('grandiose', 'plan'), 2),
#  (('causing', 'cai'), 2),
#  (('priced', 'to'), 2),
#  (('redskins', 'running'), 2),
#  (('sunderland', 'defending'), 2),
#  (('should', 'slow'), 2),
#  (('person', 'came'), 2),
#  (('kerry', 'strategists'), 2),
#  (('prix', 'according'), 2),
#  (('eyes', 'looking'), 2),
#  (('london', 'phenomenon'), 2),
#  (('that', 'hell'), 2),
#  (('routine', 'jobs'), 2),
#  (('appetite', 'suppressant'), 2),
#  (('existing', 'infrastructure'), 2),
#  (('malaythong', 's'), 2),
#  (('private', 'briefings'), 2),
#  (('dorothy', 'nyasulu'), 2),
#  (('oil', 'sheikhdom'), 2),
#  (('enjoyable', 'world'), 2),
#  (('is', 'virtualisationthis'), 2),
#  (('under21', 'world'), 2),
#  (('consume', 'everyone'), 2),
#  (('groups', 'registered'), 2),
#  (('loving', 'leo'), 2),
#  (('oligarchs', 'closest'), 2),
#  (('intellectual', 'firepower'), 2),
#  (('peruvian', 'manuel'), 2),
#  (('bed', 'about'), 2),
#  (('the', 'debs'), 2),
#  (('sets', 'mosquito'), 2),
#  (('rock', 'serves'), 2),
#  (('ran', 'short'), 2),
#  (('cosy', 'wooden'), 2),
#  (('surrender', 'weapons'), 2),
#  (('future', 'also'), 2),
#  (('inserted', 'a'), 2),
#  (('small', 'complaint'), 2),
#  (('beers', 'of'), 2),
#  (('porters', 'and'), 2),
#  (('santana', 'sits'), 2),
#  (('ferocity', 'you'), 2),
#  (('governor', 'stated'), 2),
#  (('armstrong', 'pointed'), 2),
#  (('away', 'officials'), 2),
#  (('says', 'confusion'), 2),
#  (('community', 'this'), 2),
#  (('chose', 'efron'), 2),
#  (('biggest', 'numbers'), 2),
#  (('scientific', 'development'), 2),
#  (('come', 'our'), 2),
#  (('hommet', 'access'), 2),
#  (('reinvent', 'yourself'), 2),
#  (('wake', 'road'), 2),
#  (('leading', 'al'), 2),
#  (('vital', 'is'), 2),
#  (('their', 'telescopic'), 2),
#  (('commission', 'into'), 2),
#  (('stillbirth', 'in'), 2),
#  (('capitalist', 'oppressors'), 2),
#  (('different', 'preaching'), 2),
#  (('few', 'strategies'), 2),
#  (('freedom', 'by'), 2),
#  (('their', 'silly'), 2),
#  (('cables', 'was'), 2),
#  (('arrogant', 'self'), 2),
#  (('states', 'argue'), 2),
#  (('dean', 'moeller'), 2),
#  (('72', 'began'), 2),
#  (('dominion', 'tower'), 2),
#  (('the', 'afs'), 2),
#  (('prefer', 'smaller'), 2),
#  (('stuart', 'hess'), 2),
#  (('class', 's'), 2),
#  (('kabul', 'while'), 2),
#  (('in', 'befuddlement'), 2),
#  (('month', 'pryor'), 2),
#  (('first', 'sporting'), 2),
#  (('successfully', 'flight'), 2),
#  (('rights', 'lord'), 2),
#  (('stories', 'ranging'), 2),
#  (('herd', 'a'), 2),
#  (('said', 'fyodr'), 2),
#  (('under', 'pashtunwali'), 2),
#  (('mccain', 'seeks'), 2),
#  (('admit', 'other'), 2),
#  (('is', 'peanuts'), 2),
#  (('1220', 'militants'), 2),
#  (('television', 'drtv'), 2),
#  (('third', 'however'), 2),
#  (('lieutenants', 'blame'), 2),
#  (('arbitrage', 'between'), 2),
#  (('reminisce', 'until'), 2),
#  (('favre', 'on'), 2),
#  (('doonan', 'was'), 2),
#  (('some', 'ad'), 2),
#  (('getting', 'booted'), 2),
#  (('be', 'unequaled'), 2),
#  (('improved', 'twoway'), 2),
#  (('so', 'lax'), 2),
#  (('artistic', 'merits'), 2),
#  (('and', 'reacted'), 2),
#  (('her', 'cbe'), 2),
#  (('retail', 'forward'), 2),
#  (('engineer', 'working'), 2),
#  (('the', 'throwback'), 2),
#  (('pierre', 'kremer'), 2),
#  (('only', 'cycle'), 2),
#  (('2050', 'while'), 2),
#  (('web', 'interactions'), 2),
#  (('labeled', 'palin'), 2),
#  (('its', '1992'), 2),
#  (('must', 'mature'), 2),
#  (('with', 'wars'), 2),
#  (('carey', 'mcwilliams'), 2),
#  (('potential', 'influx'), 2),
#  (('net', 'including'), 2),
#  (('yesterday', 'launched'), 2),
#  (('interview', 'lanier'), 2),
#  (('at', 'travelocity'), 2),
#  (('of', '65p'), 2),
#  (('tried', 'solely'), 2),
#  (('a', 'preflight'), 2),
#  (('people', 'nodding'), 2),
#  ...]

# %% [markdown]
# The median of bigrams count is 2.
#
# (ID: 21, time: 46s)
#
# (ID: 22, time: 47s)
#
# (ID: 23, time: 48s)
#
# (ID: 24, time: 1.5 min)
#
# (ID: 25, time: 43s)
#
# (ID: 26, time: 1.4 min)
#
# -> Total time: 5.9 min

# %% [markdown]
# When investigating the Jobs execution, I notice one interesting thing, that is sortBy() has 2 jobs ID 22 and ID 23, and eventhough sortBy() is implemented on sortByKey() which is a transformation, not an action itself. To validate this, I run below two executions and observe Spark UI

# %%
bigramCounts.sortBy(lambda z : z[1]).zipWithIndex().filter(lambda z: z[1] == int((countNumBigram - 1)/2))
# Out:
# PythonRDD[61] at RDD at PythonRDD.scala:53

# %%
bigramCounts.sortBy(lambda z : z[1])
# Out:
# PythonRDD[68] at RDD at PythonRDD.scala:53

# %% [markdown]
# (ID: 27, time: 1.2 min) and (ID: 28, time: 1.1 min) are 2 consecutive jobs of sortBy().
#
# (ID: 30, time: 52s) and (ID: 31, time: 50s) are 2 consecutive jobs of sortBy().
#
# This sound interesting to get deep understanding of what's behind, but I will leave for future investigation.
